# %%
#ASSIGNMENT 1
#Q1:_
"""OPERATOR
-STRING
-INT
-OPERAOR
-OPERATOR
OPERATOR
-INT"""
#Q2;-
""" STRING IS TYPE OF DATA AND VARIABLE IS NAME OF MEMORY LOCATION WHERE WE STORE DATA"""
#Q3
"""INTEGER
-BOOLEAN
-STRING"""
#Q4
#ans-expressions is the logical combination of operators,operands and constants.
#Q5
"""STATEMENT IS JUST COMMAND OR INSTRUCTION GIVEN BY PROGRAMMER TO COMPUTER 
AND EXPRESSION IS LOGICAL COMBINATION OF OPERANDS , OPERATORS AND CONSTANTS"""
#Q6
# BACON WILL CONTAIN 23
#Q7
1-'spamspamspam'
2-'spamspamspam'
#Q8 BECAUSE IN PYTHON , VARIABLE NAME SHOULD BE STARTED FROM ALPHABET NOT FROM NUMERIC.
#Q9 int(),float(),str()
#Q10 
'I HAVE EATEN'+99+'BURIOTS' IS ERROR BECAUSE 99 IS INTEGER , WE CAN CORRECT IT BY TYPE CASTING 99 INTO STRING.
# Out:
# 'STATEMENT IS JUST COMMAND OR INSTRUCTION GIVEN BY PROGRAMMER TO COMPUTER \nAND EXPRESSION IS LOGICAL COMBINATION OF OPERANDS , OPERATORS AND CONSTANTS'
